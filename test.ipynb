-- %%
create schema if not exists project_1.gold

-- %%
drop table project_1.gold.monthly_order_trends

-- %%
select distinct o_orderdate from samples.tpch.orders
where o_orderdate > '1995-01-01'
order by o_orderdate
